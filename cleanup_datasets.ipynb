# %%
import os
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
from collections import Counter

dataset_dir = "./datasets/CARDIS-clean"

# %%
cardis = ImageFolder(root=dataset_dir, transform=ToTensor())

# %%
# Out:
# Dataset ImageFolder
#     Number of datapoints: 48159
#     Root location: ./datasets/CARDIS-clean
#     StandardTransform
# Transform: ToTensor()

# %%
for file_path, _ in cardis.samples:  
    if "copy" in os.path.basename(file_path).lower():
        try:
            os.remove(file_path)  # Delete the file
            print(f"Deleted: {file_path}")
        except Exception as e:
            print(f"Failed to delete {file_path}: {e}")

print("Processing completed.")
# Out:
# Deleted: ./datasets/CARDIS/b/1 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/1 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/10 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/11 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/12 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/13 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/14 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/15 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/16 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/17 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/18 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/19 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/2 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/20 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/21 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/22 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/23 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/24 - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (10) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (3) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (6).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (7) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (8) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (8) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy (9) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (2) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (2) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (2).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (3) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (3).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (4).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (5) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (6) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy (7) - Copy.jpg
# Deleted: ./datasets/CARDIS/b/25 - Copy - Copy - Copy (2) - Copy.jpg
# ...
# Deleted: ./datasets/CARDIS/z/z1 - Copy (240) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (246) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (25) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (253) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (255) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (258) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (262) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (272) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (273) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (28) - Copy - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (281) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (293) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (294) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (3) - Copy - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (30) - Copy - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (302) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (303) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (305) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (311) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (320) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (33) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (331) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (334) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (336) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (338) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (338) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (339) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (341) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (38) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (4) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (4) - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (41) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (42) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (42) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (48) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (5) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (5) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (5).jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (50) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (55) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (57) - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (59) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (60) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (61) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (64) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (65) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (66) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (69) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (71) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (74) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (8) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (82) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (85) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (89) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (89) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (93) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (93) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (95) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (96) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy (99) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (10) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (10).jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (104) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (108) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (109) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (109) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (110) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (110) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (114) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (117) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (118) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (119) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (12) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (12) - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (120) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (124) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (124) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (125) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (129) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (131) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (14) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (140) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (143) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (145) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (145) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (147) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (147) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (148) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (150) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (154) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (156) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (159) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (164) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (166) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (167) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (170) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (174) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (183) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (183) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (19) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (192) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (198) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (2) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (20) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (203) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (205) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (207) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (212) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (246) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (246) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (25) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (250) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (251) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (252) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (255) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (26) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (261) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (267) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (271) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (275) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (278) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (28) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (282) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (283) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (284) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (286) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (29) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (29) - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (291) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (291) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (299) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (3) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (3) - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (30) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (31) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (312) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (313) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (319) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (32) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (320) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (326) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (327) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (33) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (331) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (332) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (334) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (35) - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (355) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (36) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (364) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (37) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (37) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (41) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (42) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (43) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (45) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (50) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (51) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (52) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (56) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (58) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (6) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (61) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (63) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (64) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (71) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (73) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (77) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (8) - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (8) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (84) - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (84) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (86) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (86) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (89) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (9).jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (95) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (96) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy (98) - Copy - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (100) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (75) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (77) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (77) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (78) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (79) - Copy - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (82) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (87) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy (90) - Copy - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy - Copy - Copy - Copy (6) - Copy - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy - Copy - Copy - Copy - Copy (5) - Copy.jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy - Copy - Copy - Copy - Copy - Copy (5).jpg
# Deleted: ./datasets/CARDIS/z/z1 - Copy - Copy - Copy - Copy - Copy - Copy - Copy - Copy - Copy - Copy - Copy.jpg
# Processing completed.

# %%
cardis = ImageFolder(root=dataset_dir, transform=ToTensor())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cardis = ImageFolder(root=dataset_dir, transform=ToTensor())
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/torchvision/datasets/folder.py:328, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     319 def __init__(
#     320     self,
#     321     root: Union[str, Path],
#    (...)
#     326     allow_empty: bool = False,
#     327 ):
# --> 328     super().__init__(
#     329         root,
#     330         loader,
#     331         IMG_EXTENSIONS if is_valid_file is None else None,
#     332         transform=transform,
#     333         target_transform=target_transform,
#     334         is_valid_file=is_valid_file,
#     335         allow_empty=allow_empty,
#     336     )
#     337     self.imgs = self.samples
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/torchvision/datasets/folder.py:150, in DatasetFolder.__init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     148 super().__init__(root, transform=transform, target_transform=target_transform)
#     149 classes, class_to_idx = self.find_classes(self.root)
# --> 150 samples = self.make_dataset(
#     151     self.root,
#     152     class_to_idx=class_to_idx,
#     153     extensions=extensions,
#     154     is_valid_file=is_valid_file,
#     155     allow_empty=allow_empty,
#     156 )
#     158 self.loader = loader
#     159 self.extensions = extensions
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/torchvision/datasets/folder.py:203, in DatasetFolder.make_dataset(directory, class_to_idx, extensions, is_valid_file, allow_empty)
#     198 if class_to_idx is None:
#     199     # prevent potential bug since make_dataset() would use the class_to_idx logic of the
#     200     # find_classes() function, instead of using that of the find_classes() method, which
#     201     # is potentially overridden and thus could have a different logic.
#     202     raise ValueError("The class_to_idx parameter cannot be None.")
# --> 203 return make_dataset(
#     204     directory, class_to_idx, extensions=extensions, is_valid_file=is_valid_file, allow_empty=allow_empty
#     205 )
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/torchvision/datasets/folder.py:104, in make_dataset(directory, class_to_idx, extensions, is_valid_file, allow_empty)
#     102     if extensions is not None:
#     103         msg += f"Supported extensions are: {extensions if isinstance(extensions, str) else ', '.join(extensions)}"
# --> 104     raise FileNotFoundError(msg)
#     106 return instances
#
# FileNotFoundError: Found no valid file for the classes v, z. Supported extensions are: .jpg, .jpeg, .png, .ppm, .bmp, .pgm, .tif, .tiff, .webp

# %%
from PIL import Image
import imagehash
import os
import pandas as pd

def compare_images_in_class(class_folder):
    """
    Compare all images in a given class folder to find duplicates and unique images.

    Args:
        class_folder (str): Path to the folder containing images of a single class.

    Returns:
        tuple: (number_of_duplicates, number_of_unique_images)
    """
    hashes = {}
    duplicates = 0

    for file in os.listdir(class_folder):
        file_path = os.path.join(class_folder, file)
        if os.path.isfile(file_path):
            with Image.open(file_path) as img:
                hash_value = imagehash.average_hash(img)
                if hash_value in hashes:
                    duplicates += 1
                else:
                    hashes[hash_value] = file_path

    unique_images = len(hashes)
    return duplicates, unique_images


def analyze_classes(dataset_folder):
    """
    Analyze all classes in the dataset and return the number of duplicates and unique images per class.

    Args:
        dataset_folder (str): Path to the dataset folder.

    Returns:
        dict: A dictionary with class names as keys and (duplicates, unique_images) as values.
    """
    results = {}
    for class_name in os.listdir(dataset_folder):
        class_folder = os.path.join(dataset_folder, class_name)
        if os.path.isdir(class_folder):
            duplicates, unique_images = compare_images_in_class(class_folder)
            results[class_name] = (duplicates, unique_images)

    return results

# %%
dataset_folder = "./datasets/DIDA-clean"
class_analysis = analyze_classes(dataset_folder)


df_results = pd.DataFrame.from_dict(class_analysis, orient="index", columns=["Duplicates", "Unique"])
df_results.index.name = "Labels"

html_output_file = "CARDIS.html"
df_results.to_html(html_output_file, index=True)

latex_output_file = "CARDIS.tex"
df_results.to_latex(latex_output_file, index=True, caption="CARDIS", label="tab:cardis-duplicate-class-analysis")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 dataset_folder = "./datasets/DIDA-clean"
# ----> 2 class_analysis = analyze_classes(dataset_folder)
#       5 df_results = pd.DataFrame.from_dict(class_analysis, orient="index", columns=["Duplicates", "Unique"])
#       6 df_results.index.name = "Labels"
#
# Cell In[4], line 47, in analyze_classes(dataset_folder)
#      45     class_folder = os.path.join(dataset_folder, class_name)
#      46     if os.path.isdir(class_folder):
# ---> 47         duplicates, unique_images = compare_images_in_class(class_folder)
#      48         results[class_name] = (duplicates, unique_images)
#      50 return results
#
# Cell In[4], line 24, in compare_images_in_class(class_folder)
#      22 with Image.open(file_path) as img:
#      23     hash_value = imagehash.average_hash(img)
# ---> 24     if hash_value in hashes:
#      25         duplicates += 1
#      26     else:
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/imagehash/__init__.py:127, in ImageHash.__hash__(self)
#     125 def __hash__(self):
#     126 	# this returns a 8 bit integer, intentionally shortening the information
# --> 127 	return sum([2**(i % 8) for i, v in enumerate(self.hash.flatten()) if v])
#
# File ~/.pyenv/versions/3.10.0/lib/python3.10/site-packages/imagehash/__init__.py:127, in <listcomp>(.0)
#     125 def __hash__(self):
#     126 	# this returns a 8 bit integer, intentionally shortening the information
# --> 127 	return sum([2**(i % 8) for i, v in enumerate(self.hash.flatten()) if v])
#
# KeyboardInterrupt:

# %%
# Example usage
dataset_folder = "./datasets/DIDA"
class_analysis = analyze_classes(dataset_folder)

# Convert the results to a DataFrame
df_results = pd.DataFrame.from_dict(class_analysis, orient="index", columns=["Duplicates", "Unique Images"])
df_results.index.name = "Labels"

html_output_file = "DIDA.html"
df_results.to_html(html_output_file, index=True)

# %%
from PIL import Image
import imagehash
import os

def compare_and_delete_duplicates(class_folder):
    """
    Compare all images in a given class folder to find and delete duplicates.

    Args:
        class_folder (str): Path to the folder containing images of a single class.

    Returns:
        tuple: (number_of_duplicates_deleted, number_of_unique_images)
    """
    hashes = {}
    duplicates = 0

    for file in os.listdir(class_folder):
        file_path = os.path.join(class_folder, file)
        if os.path.isfile(file_path):
            with Image.open(file_path) as img:
                hash_value = imagehash.average_hash(img)
                if hash_value in hashes:
                    # Duplicate found, delete the file
                    os.remove(file_path)
                    duplicates += 1
                else:
                    hashes[hash_value] = file_path

    unique_images = len(hashes)
    return duplicates, unique_images


def analyze_and_cleanup(dataset_folder):
    """
    Analyze all classes in the dataset, delete duplicates, and return the number of duplicates
    and unique images per class.

    Args:
        dataset_folder (str): Path to the dataset folder.

    Returns:
        dict: A dictionary with class names as keys and (duplicates_deleted, unique_images) as values.
    """
    results = {}
    for class_name in os.listdir(dataset_folder):
        class_folder = os.path.join(dataset_folder, class_name)
        if os.path.isdir(class_folder):
            duplicates, unique_images = compare_and_delete_duplicates(class_folder)
            results[class_name] = (duplicates, unique_images)

    return results

# %%
dataset_folder = "./datasets/DIDA-clean"
cleanup_results = analyze_and_cleanup(dataset_folder)

for class_name, (duplicates_deleted, unique_images) in cleanup_results.items():
    print(f"Class: {class_name} | Duplicates Deleted: {duplicates_deleted} | Unique Images: {unique_images}")
# Out:
# Class: 5 | Duplicates Deleted: 124 | Unique Images: 25565
# Class: 6 | Duplicates Deleted: 101 | Unique Images: 25605
# Class: 0 | Duplicates Deleted: 289 | Unique Images: 24751
# Class: 2 | Duplicates Deleted: 15 | Unique Images: 25137
# Class: 8 | Duplicates Deleted: 197 | Unique Images: 25167
# Class: 1 | Duplicates Deleted: 1295 | Unique Images: 23707
# Class: 9 | Duplicates Deleted: 137 | Unique Images: 24970
# Class: 4 | Duplicates Deleted: 90 | Unique Images: 25318
# Class: 3 | Duplicates Deleted: 31 | Unique Images: 25018
# Class: 7 | Duplicates Deleted: 83 | Unique Images: 25260

# %%
import shutil

def remove_small_classes(dataset_folder, min_elements=30):
    """
    Remove classes (folders) that contain fewer than the specified number of elements.

    Args:
        dataset_folder (str): Path to the dataset folder.
        min_elements (int): Minimum number of elements required to keep a class.

    Returns:
        list: List of class names that were deleted.
    """
    deleted_classes = []

    for class_name in os.listdir(dataset_folder):
        class_folder = os.path.join(dataset_folder, class_name)
        if os.path.isdir(class_folder):
            # Count the number of files in the class folder
            num_files = len([f for f in os.listdir(class_folder) if os.path.isfile(os.path.join(class_folder, f))])
            
            # Check if the folder has fewer than the minimum required elements
            if num_files < min_elements:
                # Delete the folder and log its name
                shutil.rmtree(class_folder)
                deleted_classes.append(class_name)

    return deleted_classes

# Example Usage
dataset_folder = "./datasets/CARDIS-class-removed"
deleted_classes = remove_small_classes(dataset_folder, min_elements=30)

print(f"Deleted classes with fewer than 30 elements: {deleted_classes}")
# Out:
# Deleted classes with fewer than 30 elements: ['x', 'z', 'r', 'w', 'v', 'y']
